# %%
import Fish_data

# %%
f = Fish_data.Fish()
# Out:
# Files have been downloaded and cleaned. To access the data call get_fish_data() and get_water_data() functions.

# %%
fish_data = f.get_fish_data()
water_data = f.get_water_data()

# %%
fish_data.head()
# Out:
#      FishID                 Date  TREND Gear Species  Sex  Length   Mass  \
# 0  19710001  1971-03-09 00:00:00      1   GN     LMB  NaN     263  250.0
# 1  19710002  1971-03-09 00:00:00      1   GN     LMB  NaN     348  700.0
# 2  19710003  1971-03-09 00:00:00      1   GN     LMB  NaN     332  555.0
# 3  19710004  1971-03-09 00:00:00      1   GN     LMB  NaN     350  720.0
# 4  19710005  1971-03-09 00:00:00      1   GN     LMB  NaN     300  455.0
#
#     Ktl  Weight  ... parasite  misc 1 text  misc 2 num  misc 3 text  \
# 0  1.37     0.0  ...      NaN          NaN         NaN          NaN
# 1  1.66     0.0  ...      NaN          NaN         NaN          NaN
# 2  1.51     0.0  ...      NaN          NaN         NaN          NaN
# 3  1.67     0.0  ...      NaN          NaN         NaN          NaN
# 4  1.68     0.0  ...      NaN          NaN         NaN          NaN
#
#    misc 4 num  Site  KFL  Day  Month  Year
# 0         NaN    RN  0.0    9      3  1971
# ...

# %%
fish_data.columns
# Out:
# Index(['FishID', 'Date', 'TREND', 'Gear', 'Species', 'Sex', 'Length', 'Mass',
#        'Ktl', 'Weight', 'Maturity', 'Age structure', 'stomach', 'gonads',
#        'fat_index', 'parasite', 'misc 1 text', 'misc 2 num', 'misc 3 text',
#        'misc 4 num', 'Site', 'KFL', 'Day', 'Month', 'Year'],
#       dtype='object')
# Index(['FishID', 'Date', 'TREND', 'Gear', 'Species', 'Sex', 'Length', 'Mass',
#        'Ktl', 'Weight', 'Maturity', 'Age structure', 'stomach', 'gonads',
#        'fat_index', 'parasite', 'misc 1 text', 'misc 2 num', 'misc 3 text',
#        'misc 4 num', 'Site', 'KFL', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
water_data.head()
# Out:
#    Unnamed: 0      DATE MEASURED  ELEVATION  CONTENT  INFLOW  OUTFLOW  \
# 0           1  Thu, Mar 14, 1963        NaN      NaN    4748     1300
# 1           2  Fri, Mar 15, 1963        NaN      NaN    4730     1260
# 2           3  Sat, Mar 16, 1963        NaN      NaN    4793     1220
# 3           4  Sun, Mar 17, 1963        NaN      NaN    4748     1260
# 4           5  Mon, Mar 18, 1963        NaN      NaN    4532     1210
#
#    HIGH TEMP  LOW TEMP  WATER  MONTH  DAY  YEAR
# 0       58.0      28.0    NaN      3   14  1963
# 1       58.0      26.0    NaN      3   15  1963
# 2       47.0      29.0    NaN      3   16  1963
# 3       50.0      36.0    NaN      3   17  1963
# 4       48.0      32.0    NaN      3   18  1963
#    Unnamed: 0      DATE MEASURED  ELEVATION  CONTENT  INFLOW  OUTFLOW  \
# 0           1  Thu, Mar 14, 1963        NaN      NaN    4748     1300
# 1           2  Fri, Mar 15, 1963        NaN      NaN    4730     1260
# ...
